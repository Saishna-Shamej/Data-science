# %% [markdown]
# <a href="https://colab.research.google.com/github/Saishna-Shamej/Data-science/blob/main/Pandas_Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataframes**
#
# Workhorse of pandas and are directly inspired by R programming language.
# dataframes are a bunch of series objects put together to share the same index.

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y z'.split())
df
# Out:
#           W         X         Y         z
# A  0.188695 -0.758872 -0.933237  0.955057
# B  0.190794  1.978757  2.605967  0.683509
# C  0.302665  1.693723 -1.706086 -1.159119
# D -0.134841  0.390528  0.166905  0.184502
# E  0.807706  0.072960  0.638787  0.329646

# %%
df['X']
# Out:
# A   -0.758872
# B    1.978757
# C    1.693723
# D    0.390528
# E    0.072960
# Name: X, dtype: float64

# %%
df[['W','X']]
# Out:
#           W         X
# A  0.188695 -0.758872
# B  0.190794  1.978757
# C  0.302665  1.693723
# D -0.134841  0.390528
# E  0.807706  0.072960

# %%
df.W
# Out:
# A    0.188695
# B    0.190794
# C    0.302665
# D   -0.134841
# E    0.807706
# Name: W, dtype: float64

# %%
df.X
# Out:
# A    0.628133
# B    0.651118
# C    0.605965
# D    0.528813
# Name: X, dtype: float64

# %%
type(df.X)
# Out:
# pandas.core.series.Series

# %%
df['new']= df['W']+df['Y']
df
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.614819
# B  0.503826  0.651118 -0.319318  0.184508
# C -0.848077  0.605965 -2.018168 -2.866245
# D  0.740122  0.528813 -0.589001  0.151122

# %%
df.drop('new',axis = 1)
df
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.614819
# B  0.503826  0.651118 -0.319318  0.184508
# C -0.848077  0.605965 -2.018168 -2.866245
# D  0.740122  0.528813 -0.589001  0.151122

# %%
df.drop('new',axis = 1,inplace=True)
df
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df.drop('D', axis=0)
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168

# %%
df.drop('C',axis=0)
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# D  0.740122  0.528813 -0.589001

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Name: A, dtype: float64

# %%
df.iloc[3]
# Out:
# W    0.740122
# X    0.528813
# Y   -0.589001
# Name: D, dtype: float64

# %%
df.loc['B','X']
# Out:
# 0.6511179479432686

# %%
df.loc[['A','B'],['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B  0.651118 -0.319318

# %%
df
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df>0
# Out:
#        W     X      Y
# A   True  True   True
# B   True  True  False
# C  False  True  False
# D   True  True  False

# %%
df[df>0]
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118       NaN
# C       NaN  0.605965       NaN
# D  0.740122  0.528813       NaN

# %%
df[df['W']>0]['X']
# Out:
# A    0.628133
# B    0.651118
# D    0.528813
# Name: X, dtype: float64

# %%
df[df['W']>0][['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B  0.651118 -0.319318
# D  0.528813 -0.589001

# %%
df
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df[(df['W']>0) & (df['X'] > 1)]
# Out:
#           W         X         Y         z
# B  0.190794  1.978757  2.605967  0.683509
# C  0.302665  1.693723 -1.706086 -1.159119

# %%
df
# Out:
#           W         X         Y         z
# A  0.188695 -0.758872 -0.933237  0.955057
# B  0.190794  1.978757  2.605967  0.683509
# C  0.302665  1.693723 -1.706086 -1.159119
# D -0.134841  0.390528  0.166905  0.184502
# E  0.807706  0.072960  0.638787  0.329646

# %%
df.reset_index()
# Out:
#   index         W         X         Y         z
# 0     A  0.188695 -0.758872 -0.933237  0.955057
# 1     B  0.190794  1.978757  2.605967  0.683509
# 2     C  0.302665  1.693723 -1.706086 -1.159119
# 3     D -0.134841  0.390528  0.166905  0.184502
# 4     E  0.807706  0.072960  0.638787  0.329646

# %%
newind = 'CA NY WY OR CO'.split()
df['States'] = newind
df
# Out:
#                W         X         Y         z States
# States
# CA      0.188695 -0.758872 -0.933237  0.955057     CA
# NY      0.190794  1.978757  2.605967  0.683509     NY
# WY      0.302665  1.693723 -1.706086 -1.159119     WY
# OR     -0.134841  0.390528  0.166905  0.184502     OR
# CO      0.807706  0.072960  0.638787  0.329646     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         z
# States
# CA      0.188695 -0.758872 -0.933237  0.955057
# NY      0.190794  1.978757  2.605967  0.683509
# WY      0.302665  1.693723 -1.706086 -1.159119
# OR     -0.134841  0.390528  0.166905  0.184502
# CO      0.807706  0.072960  0.638787  0.329646

# %%
df
# Out:
#                W         X         Y         z States
# States
# CA      0.188695 -0.758872 -0.933237  0.955057     CA
# NY      0.190794  1.978757  2.605967  0.683509     NY
# WY      0.302665  1.693723 -1.706086 -1.159119     WY
# OR     -0.134841  0.390528  0.166905  0.184502     OR
# CO      0.807706  0.072960  0.638787  0.329646     CO

# %%
df.set_index('States',inplace=True)
df
# Out:
#                W         X         Y         z
# States
# CA      0.188695 -0.758872 -0.933237  0.955057
# NY      0.190794  1.978757  2.605967  0.683509
# WY      0.302665  1.693723 -1.706086 -1.159119
# OR     -0.134841  0.390528  0.166905  0.184502
# CO      0.807706  0.072960  0.638787  0.329646

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1 -0.497104 -0.754070
#    2 -0.943406  0.484752
#    3 -0.116773  1.901755
# G2 1  0.238127  1.996652
#    2 -0.993263  0.196800
#    3 -1.136645  0.000366

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.497104 -0.754070
# 2 -0.943406  0.484752
# 3 -0.116773  1.901755

# %%
df.loc['G1'].loc[1]
# Out:
# A   -0.497104
# B   -0.754070
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.497104 -0.754070
#       2   -0.943406  0.484752
#       3   -0.116773  1.901755
# G2    1    0.238127  1.996652
#       2   -0.993263  0.196800
#       3   -1.136645  0.000366

# %%
df.xs(["G1"])
# Out:
# <ipython-input-110-46e809d3d9a5>:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   df.xs(["G1"])
#             A         B
# Num
# 1   -0.497104 -0.754070
# 2   -0.943406  0.484752
# 3   -0.116773  1.901755

# %%
df.xs(['G1',1])
# Out:
# <ipython-input-112-c549ee06ce91>:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   df.xs(['G1',1])
# A   -0.497104
# B   -0.754070
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1    -0.497104 -0.754070
# G2     0.238127  1.996652
