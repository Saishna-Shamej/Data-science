# %% [markdown]
# <a href="https://colab.research.google.com/github/Saishna-Shamej/Data-science/blob/main/Matplotlib_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exercise 1**

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.plot(x, y, 'b')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# # **Exercise 2**

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1]) #ax1
axes2 = fig.add_axes([0.2,0.5,.2,.2]) #ax2

# %%
fig=plt.figure()
axes1 = fig.add_axes([0,0,1,1]) #ax1
axes2 = fig.add_axes([0.2,0.5,.2,.2]) #ax2
#ax1
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
#ax2
axes2.plot(y, x, 'r')
axes2.set_xlabel('x')
axes2.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # **Exercise 3**

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1]) #ax1
axes2 = fig.add_axes([0.2,0.5,.4,.4]) #ax2

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1]) #ax1
axes2 = fig.add_axes([0.2,0.5,.4,.4]) #ax2

axes1.plot(x,z)
axes1.set_xlabel('x')
axes1.set_ylabel('z')

axes2.plot(x,y)
axes2.set_xlabel('x')
axes2.set_ylabel('z')
axes2.set_xlim([20,22])
axes2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %% [markdown]
# # **Exercise 4**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes[0].plot(x,y,linestyle='--', color = 'blue')
axes[1].plot(x,z,linestyle='-', color = 'red')
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize =(10,2))

# %%
axes[0].plot(x,y,linestyle='--', color = 'blue')
axes[1].plot(x,z,linestyle='-', color = 'red')
fig
