# %% [markdown]
# <a href="https://colab.research.google.com/github/Saishna-Shamej/Data-science/blob/main/Pandas_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4,6],'col2':[333,555,666,444,777],'col3':['abc','defk','ghi','xyz','ghi'], 'col4':[7,8,9,np.nan,np.nan],'col5':[np.nan,555,666,444,888], 'col5':['abc','def','ghi','xyz','pqrs']})

df.head()
# Out:
#    col1  col2  col3  col4  col5
# 0     1   333   abc   7.0   abc
# 1     2   555  defk   8.0   def
# 2     3   666   ghi   9.0   ghi
# 3     4   444   xyz   NaN   xyz
# 4     6   777   ghi   NaN  pqrs

# %%
df.head(2)
# Out:
#    col1  col2  col3  col4 col5
# 0     1   333   abc   7.0  abc
# 1     2   555  defk   8.0  def

# %%
df['col1'].unique()
# Out:
# array([1, 2, 3, 4, 6])

# %%
df['col1'].nunique()
# Out:
# 5

# %%
df['col3'].value_counts()
# Out:
# ghi     2
# abc     1
# defk    1
# xyz     1
# Name: col3, dtype: int64

# %%
newdf = df[(df['col1']>1) & (df['col2']==444)]

# %%
newdf
# Out:
#    col1  col2 col3  col4 col5
# 3     4   444  xyz   NaN  xyz

# %%
def times2(x):
  return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    12
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    4
# 2    3
# 3    3
# 4    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()
# Out:
# 16

# %%
del df['col1']

# %%
df
# Out:
#    col2  col3  col4  col5
# 0   333   abc   7.0   abc
# 1   555  defk   8.0   def
# 2   666   ghi   9.0   ghi
# 3   444   xyz   NaN   xyz
# 4   777   ghi   NaN  pqrs

# %%
df.columns
# Out:
# Index(['col2', 'col3', 'col4', 'col5'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df
# Out:
#    col2  col3  col4  col5
# 0   333   abc   7.0   abc
# 1   555  defk   8.0   def
# 2   666   ghi   9.0   ghi
# 3   444   xyz   NaN   xyz
# 4   777   ghi   NaN  pqrs

# %%
df.sort_values(by='col2')
# Out:
#    col2  col3  col4  col5
# 0   333   abc   7.0   abc
# 3   444   xyz   NaN   xyz
# 1   555  defk   8.0   def
# 2   666   ghi   9.0   ghi
# 4   777   ghi   NaN  pqrs

# %%
df.isnull()
# Out:
#     col2   col3   col4   col5
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4  False  False   True  False

# %%
df.dropna()
# Out:
#    col2  col3  col4 col5
# 0   333   abc   7.0  abc
# 1   555  defk   8.0  def
# 2   666   ghi   9.0  ghi

# %%
import numpy as np
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna('Fill')
# Out:
#    col1   col2 col3
# 0   1.0   Fill  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3  Fill  444.0  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN
